# %%
import pandas as pd

# %%
meteorData = pd.read_csv("Meteorite_Landings.csv")
meteorData.head()
# Out:
#        name   id nametype     recclass  mass (g)  fall  \
# 0    Aachen    1    Valid           L5      21.0  Fell
# 1    Aarhus    2    Valid           H6     720.0  Fell
# 2      Abee    6    Valid          EH4  107000.0  Fell
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell
# 4   Achiras  370    Valid           L6     780.0  Fell
#
#                      year    reclat    reclong           GeoLocation  States  \
# 0  01/01/1880 12:00:00 AM  50.77500    6.08333     (50.775, 6.08333)     NaN
# 1  01/01/1951 12:00:00 AM  56.18333   10.23333  (56.18333, 10.23333)     NaN
# 2  01/01/1952 12:00:00 AM  54.21667 -113.00000    (54.21667, -113.0)     NaN
# 3  01/01/1976 12:00:00 AM  16.88333  -99.90000     (16.88333, -99.9)     NaN
# 4  01/01/1902 12:00:00 AM -33.16667  -64.95000   (-33.16667, -64.95)     NaN
#
#    Counties
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
meteorDataClean = meteorData.drop(columns=["States", "Counties", "fall", "nametype", "id"]).dropna()
meteorDataClean.head()
# Out:
#        name     recclass  mass (g)                    year    reclat  \
# 0    Aachen           L5      21.0  01/01/1880 12:00:00 AM  50.77500
# 1    Aarhus           H6     720.0  01/01/1951 12:00:00 AM  56.18333
# 2      Abee          EH4  107000.0  01/01/1952 12:00:00 AM  54.21667
# 3  Acapulco  Acapulcoite    1914.0  01/01/1976 12:00:00 AM  16.88333
# 4   Achiras           L6     780.0  01/01/1902 12:00:00 AM -33.16667
#
#      reclong           GeoLocation
# 0    6.08333     (50.775, 6.08333)
# 1   10.23333  (56.18333, 10.23333)
# 2 -113.00000    (54.21667, -113.0)
# 3  -99.90000     (16.88333, -99.9)
# 4  -64.95000   (-33.16667, -64.95)

# %%
meteorDataClean['year'] = meteorDataClean['year'].str.split(" ").str[0]

# %%
meteorDataClean['year'] = meteorDataClean['year'].str.split("/").str[-1]

# %%
meteorDataClean = meteorDataClean.reset_index()
meteorDataClean = meteorDataClean.rename(columns={"index": "id", "mass (g)": "mass_grams"})
meteorDataClean = meteorDataClean.set_index("id")

# %%
meteorDataClean.head()
# Out:
#         name     recclass  mass_grams  year    reclat    reclong  \
# id
# 0     Aachen           L5        21.0  1880  50.77500    6.08333
# 1     Aarhus           H6       720.0  1951  56.18333   10.23333
# 2       Abee          EH4    107000.0  1952  54.21667 -113.00000
# 3   Acapulco  Acapulcoite      1914.0  1976  16.88333  -99.90000
# 4    Achiras           L6       780.0  1902 -33.16667  -64.95000
#
#              GeoLocation
# id
# 0      (50.775, 6.08333)
# 1   (56.18333, 10.23333)
# 2     (54.21667, -113.0)
# 3      (16.88333, -99.9)
# 4    (-33.16667, -64.95)

# %%
meteorDataClean.to_csv("Clean_Meteor_Data.csv")

# %%
meteorDataClean.to_json("Clean_Meteor_Data.json")
