# %%
# %matplotlib inline 

#Dependencies 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.pylab as plb
from scipy import stats
plt.close('all')

# %%
# %matplotlib inline 

#Dependencies 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.pylab as plb
from scipy import stats

# %%
# File to Load
clean_meteor_data_data_to_load = "resources/clean_meteor_data.csv"

# Read the clean meteor data
clean_meteor_data = pd.read_csv("resources/clean_meteor_data.csv")

# %%
clean_meteor_data.head(50)
# Out:
#     id                    name       recclass  mass_grams  year    reclat  \
# 0    0                  Aachen             L5        21.0  1880  50.77500
# 1    1                  Aarhus             H6       720.0  1951  56.18333
# 2    2                    Abee            EH4    107000.0  1952  54.21667
# 3    3                Acapulco    Acapulcoite      1914.0  1976  16.88333
# 4    4                 Achiras             L6       780.0  1902 -33.16667
# 5    5                Adhi Kot            EH4      4239.0  1919  32.10000
# 6    6     Adzhi-Bogdo (stone)          LL3-6       910.0  1949  44.83333
# 7    7                    Agen             H5     30000.0  1814  44.21667
# 8    8                  Aguada             L6      1620.0  1930 -31.60000
# 9    9           Aguila Blanca              L      1440.0  1920 -30.86667
# 10  10        Aioun el Atrouss   Diogenite-pm      1000.0  1974  16.39806
# 11  11                     Aïr             L6     24000.0  1925  19.08333
# 12  13                   Akaba             L6       779.0  1949  29.51667
# 13  14                Akbarpur             H4      1800.0  1838  29.71667
# 14  15                 Akwanga              H      3000.0  1959   8.91667
# 15  16                 Akyumak      Iron, IVA     50000.0  1981  39.91667
# 16  17                 Al Rais         CR2-an       160.0  1957  24.41667
# 17  18               Al Zarnkh            LL5       700.0  2001  13.66033
# 18  19                   Alais            CI1      6000.0  1806  44.11667
# 19  20                Albareto          L/LL4      2000.0  1766  44.65000
# 20  21                 Alberta              L       625.0  1949   2.00000
# 21  22         Alby sur Chéran  Eucrite-mmict       252.0  2002  45.82133
# 22  23               Aldsworth            LL5       700.0  1835  51.78333
# 23  24                  Aleppo             L6      3200.0  1873  36.23333
# 24  25             Alessandria             H5       908.0  1860  44.88333
# 25  26           Alexandrovsky             H4      9251.0  1900  50.95000
# 26  27              Alfianello             L6    228000.0  1883  45.26667
# 27  28                 Allegan             H5     32000.0  1899  42.53333
# 28  29                 Allende            CV3   2000000.0  1969  26.96667
# 29  30          Almahata Sitta    Ureilite-an      3950.0  2008  20.74575
# 30  31              Alta'ameem            LL5      6000.0  1977  35.27333
# 31  32           Ambapur Nagla             H5      6400.0  1895  27.66667
# 32  33                 Andhara     Stone-uncl      2700.0  1880  26.58333
# 33  34                 Andover             L6      3200.0  1898  44.61667
# 34  35               Andreevka             L3       600.0  1969  48.70000
# 35  36                  Andura             H6     17900.0  1939  20.88333
# 36  39  Angra dos Reis (stone)        Angrite      1500.0  1869 -22.96667
# 37  40                 Ankober             H4      6500.0  1942   9.53333
# 38  41                  Anlong             H5      2500.0  1971  25.15000
# 39  42                  Aomori             L6       320.0  1984  40.81056
# 40  43           Appley Bridge            LL6     15000.0  1914  53.58333
# 41  44                     Apt             L6      3200.0  1803  43.86667
# 42  45              Arbol Solo             H5       810.0  1954 -33.00000
# 43  46                  Archie             H6      5070.0  1932  38.50000
# 44  47           Arroyo Aguiar             H5      7450.0  1950 -31.41667
# 45  48                    Asco             H6        41.0  1805  42.45000
# 46  49               Ash Creek             L6      9500.0  2009  31.80500
# 47  50                  Ashdon             L6      1300.0  1923  52.05000
# 48  51                  Assisi             H5      2000.0  1886  43.03333
# 49  52                  Atarra             L4      1280.0  1920  25.25417
#
#       reclong             GeoLocation
# 0     6.08333       (50.775, 6.08333)
# 1    10.23333    (56.18333, 10.23333)
# 2  -113.00000      (54.21667, -113.0)
# 3   -99.90000       (16.88333, -99.9)
# 4   -64.95000     (-33.16667, -64.95)
# 5    71.80000            (32.1, 71.8)
# 6    95.16667    (44.83333, 95.16667)
# 7     0.61667     (44.21667, 0.61667)
# 8   -65.23333      (-31.6, -65.23333)
# 9   -64.55000     (-30.86667, -64.55)
# 10   -9.57028    (16.39806, -9.57028)
# 11    8.38333     (19.08333, 8.38333)
# 12   35.05000       (29.51667, 35.05)
# 13   77.95000       (29.71667, 77.95)
# 14    8.43333      (8.91667, 8.43333)
# 15   42.81667    (39.91667, 42.81667)
# 16   39.51667    (24.41667, 39.51667)
# 17   28.96000       (13.66033, 28.96)
# 18    4.08333     (44.11667, 4.08333)
# 19   11.01667       (44.65, 11.01667)
# 20   22.66667         (2.0, 22.66667)
# 21    6.01533     (45.82133, 6.01533)
# 22   -1.78333    (51.78333, -1.78333)
# 23   37.13333    (36.23333, 37.13333)
# 24    8.75000        (44.88333, 8.75)
# 25   31.81667       (50.95, 31.81667)
# 26   10.15000       (45.26667, 10.15)
# 27  -85.88333   (42.53333, -85.88333)
# 28 -105.31667  (26.96667, -105.31667)
# 29   32.41275    (20.74575, 32.41275)
# 30   44.21556    (35.27333, 44.21556)
# 31   78.25000       (27.66667, 78.25)
# 32   85.56667    (26.58333, 85.56667)
# 33  -70.75000      (44.61667, -70.75)
# 34   37.50000            (48.7, 37.5)
# 35   76.86667    (20.88333, 76.86667)
# 36  -44.31667  (-22.96667, -44.31667)
# 37   39.71667     (9.53333, 39.71667)
# 38  105.18333      (25.15, 105.18333)
# 39  140.78556   (40.81056, 140.78556)
# 40   -2.71667    (53.58333, -2.71667)
# 41    5.38333     (43.86667, 5.38333)
# 42  -66.00000          (-33.0, -66.0)
# 43  -94.30000           (38.5, -94.3)
# 44  -60.66667  (-31.41667, -60.66667)
# 45    9.03333        (42.45, 9.03333)
# 46  -97.01000        (31.805, -97.01)
# 47    0.30000            (52.05, 0.3)
# 48   12.55000       (43.03333, 12.55)
# 49   80.62500      (25.25417, 80.625)

# %%
clean_meteor_data.count()
# Out:
# id             38114
# name           38114
# recclass       38114
# mass_grams     38114
# year           38114
# reclat         38114
# reclong        38114
# GeoLocation    38114
# dtype: int64

# %%
clean_meteor_data["year"].sum()
# Out:
# 75846517

# %%
clean_meteor_data["recclass"].count()
# Out:
# 38114

# %%
clean_meteor_data["year"].count()
# Out:
# 38114

# %%
clean_meteor_data = clean_meteor_data[["recclass", "year"]]
clean_meteor_data.head()
# Out:
#       recclass  year
# 0           L5  1880
# 1           H6  1951
# 2          EH4  1952
# 3  Acapulcoite  1976
# 4           L6  1902

# %%
clean_meteor_data.head(38115).groupby('year').size()
# Out:
# year
# 860        1
# 1399       1
# 1490       1
# 1491       1
# 1575       1
# 1583       1
# 1600       1
# 1621       1
# 1623       1
# 1628       1
# 1632       1
# 1637       1
# 1668       1
# 1671       1
# 1688       1
# 1715       1
# 1716       1
# 1723       1
# 1724       1
# 1740       1
# 1741       1
# 1749       1
# 1751       1
# 1753       2
# 1766       1
# 1768       2
# 1773       1
# 1775       1
# 1776       1
# 1781       1
#         ...
# 1984     402
# 1985     377
# 1986    1374
# 1987     914
# 1988    2295
# 1989     135
# 1990    1506
# 1991     869
# 1992     372
# 1993     976
# 1994     717
# 1995     484
# 1996     573
# 1997    1505
# 1998    2147
# 1999    1592
# 2000    1502
# 2001    1339
# 2002    1066
# 2003    1754
# 2004     366
# 2005     328
# 2006    1616
# 2007    1038
# 2008     936
# 2009    1496
# 2010    1005
# 2011     713
# 2012     234
# 2013      11
# Length: 252, dtype: int64

# %%
clean_meteor_data.head(38115).groupby('recclass').size()
# Out:
# recclass
# Acapulcoite               37
# Acapulcoite/Lodranite      5
# Acapulcoite/lodranite      1
# Achondrite-prim            3
# Achondrite-ung            36
# Angrite                   10
# Aubrite                   53
# Aubrite-an                 5
# Brachinite                23
# C                          8
# C1/2-ung                   1
# C2                         1
# C2-ung                    13
# C3-ung                    10
# C3.0-ung                   1
# C4                         2
# C4-ung                     3
# C4/5                       1
# C5/6-ung                   1
# C6                         2
# CB                         6
# CBa                        4
# CBb                        4
# CH/CBb                     1
# CH3                       19
# CI1                        7
# CK                         1
# CK3                        7
# CK3-an                     2
# CK4                       54
#                         ...
# OC                        69
# Pallasite                 16
# Pallasite, PES             3
# Pallasite, PMG            35
# Pallasite, PMG-an         11
# Pallasite, ungrouped       4
# Pallasite?                 1
# R                          1
# R3                         9
# R3-4                       1
# R3-5                       2
# R3-6                       4
# R3.5-4                     1
# R3.5-6                     1
# R3.6                       2
# R3.8                       4
# R3.8-5                     1
# R3.8-6                     3
# R3.9                       1
# R4                        16
# R5                        14
# R6                         3
# Relict OC                 17
# Relict iron                1
# Stone-uncl                29
# Stone-ung                  1
# Ureilite                 214
# Ureilite-an                3
# Ureilite-pmict            18
# Winonaite                 18
# Length: 422, dtype: int64

# %%
clean_meteor_data.head(38115).groupby('recclass').count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-163994bbb5fe> in <module>
# ----> 1 clean_meteor_data.head(38115).groupby('recclass').count()
#
# NameError: name 'clean_meteor_data' is not defined

# %%
users = clean_meteor_data ["year"]
x_axis = np.arange(len(users))

# %%
plt.bar(x_axis, users, color='r', alpha=0.5, align="center")
# Out:
# <BarContainer object of 38114 artists>
